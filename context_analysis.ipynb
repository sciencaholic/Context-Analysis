# %%
import warnings
warnings.filterwarnings('ignore')

from __future__ import division, print_function, unicode_literals

import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import pandas as pd
import math

from IPython.display import display, HTML

# %% [markdown]
# Dataset: https://www.kaggle.com/snapcrack/all-the-news

# %%
import random
path = '/home/pratikshasahu/Documents/EIDETIA/env/data/articles1.csv'

df = pd.read_csv(path, skiprows=0, nrows=1000)
df.rename(columns={'Unnamed: 0':'index'}, inplace=True)

df.head(5)
# Out:
#    index     id                                              title  \
# 0      0  17283  House Republicans Fret About Winning Their Hea...
# 1      1  17284  Rift Between Officers and Residents as Killing...
# 2      2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...

# %% [markdown]
# English stopwords list used below was built by Gerard Salton and Chris Buckley for the experimental SMART information retrieval system at Cornell University. It is available here: http://www.lextek.com/manuals/onix/stopwords2.html

# %%
import nltk
import re
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

myfile = open('/home/pratikshasahu/Documents/EIDETIA/env/smart_stopwords.txt')
stop_words = myfile.read().split()
myfile.close()

corpus = []

for i in range(len(df['index'])):
    text = re.sub('[^a-zA-Z]', ' ', df['content'][i]) # remove punctuations
    text = text.lower()                               # convert to lowercase
    text = re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",text)  # remove tags
    text = re.sub("(\\d|\\W)+"," ",text)              # remove special characters and digits
    text = text.split()                               # convert to list from string
    
    lem = WordNetLemmatizer()                         # lemmatisation
    text = [lem.lemmatize(word) for word in text if not word in stop_words] 
    
    text = " ".join(text)
    
    corpus.append(text)

corpus[:5]
# Out:
# ['washington congressional republican fear health care lawsuit obama administration win incoming trump administration choose longer defend executive branch suit challenge administration authority spend billion dollar health insurance subsidy american handing house republican big victory issue sudden loss disputed subsidy conceivably health care program implode leaving million people access health insurance republican prepared replacement lead chaos insurance market spur political backlash republican gain full control government stave outcome republican find awkward position appropriating huge sum temporarily prop obama health care law angering conservative voter demanding end law year twist donald trump administration worried preserving executive branch prerogative choose fight republican ally house central question dispute eager avoid ugly political pileup republican capitol hill trump transition team gaming handle lawsuit election put limbo late february united state court appeal district columbia circuit ready divulge strategy pending litigation involves obama administration congress inappropriate comment phillip blando spokesman trump transition effort taking office trump administration evaluate case related aspect affordable care act potentially decision judge rosemary collyer ruled house republican standing sue executive branch spending dispute obama administration distributing health insurance subsidy violation constitution approval congress justice department confident judge collyer decision reversed quickly appealed subsidy remained place appeal successfully seeking temporary halt proceeding trump won house republican month told court transition team discussing potential option resolution matter effect inauguration jan suspension case house lawyer provide future administration time continue prosecuting resolve appeal republican leadership official house acknowledge possibility cascading effect payment totaled estimated billion suddenly stopped insurer receive subsidy exchange paying cost deductible eligible consumer race drop coverage losing money loss subsidy destabilize entire program lack confidence lead insurer seek quick exit anticipating trump administration inclined mount vigorous fight house republican dim view health care law team lawyer month sought intervene case behalf participant health care program request lawyer predicted deal house republican administration dismiss settle case produce devastating consequence individual receive reduction nation health insurance health care system generally matter house republican prevail overarching concept congressional power purse congress sue executive branch violates constitution spending power house republican contend congress appropriated money subsidy required constitution suit initially championed john boehner house speaker time house committee report republican asserted administration desperate funding required treasury department provide widespread internal skepticism spending proper white house spending permanent part law passed annual appropriation required administration initially sought important house republican judge collyer found congress standing sue white house issue ruling legal expert flawed precedent set restore congressional leverage executive branch spending power standing trump administration pressure advocate presidential authority fight house matter shared view health care precedent broad repercussion complicated set dynamic illustrating quick legal victory house trump era cost republican anticipated obama white house',
ed attack entire generation postwar guy game arnie woman athletically blessed magnetically cool telegenically handsome gordie howe hockey son saskatchewan prairie tore national hockey league hung skate died ralph branca trolley car conductor son living reminder crushing mistake fastball bobby thomson decided national league pennant lived pat summitt coach elevated woman basketball led tennessee team championship won game college coach defeat alzheimer disease dying month national basketball association lost giant era clyde lovelette olympic college champion transformed game big men hardwood heir nate thurmond defensive stalwart battled russell wilt kareem paint hall fame career older baseball rank monte irvin died people remember watching play prime star negro circuit barred major league made hall fame york giant major league baseball black executive died fan pondered question hung athletic career shackled discrimination question sphere arose stunning news justice antonin scalia died hunting trip texas thick consequential supreme court career modern time left void conservative jurisprudence urgently vacancy bench filled raising question await country exit public stage returned past nancy reagan death evoked white house glamour west coast conservatism residence bank potomac john glenn thinking burst national pride soaring outer space death tom hayden daniel berrigan avatar defiance harked back student rebellion vietnam war roiling home front phyllis schlafly obituary window root wing ascension american politics death janet reno woman serve attorney general recalled clinton year firestorm waco tex international tug war cuban boy named eli gonz lez bitter senate battle impeachment shore fidel castro death summoned memory cuban revolution nuclear brinkmanship enduring enmity strongman superpower mile boutros egyptian diplomat led  ...
#  'seoul south korea north korea leader kim sunday country making final preparation conduct test intercontinental ballistic missile bold statement month inauguration donald trump north korea conducted nuclear test decade ballistic missile test habitually threatens attack united state nuclear weapon country intercontinental ballistic missile icbm annual year day speech broadcast north kctv sunday kim spoke proudly stride country made nuclear weapon ballistic missile program north korea continue bolster weapon program long united state remained hostile continued joint military exercise south korea reached final stage preparation intercontinental ballistic rocket analyst region kim conduct weapon test coming month taking advantage leadership united state south korea trump sworn jan south korea president park power suspended parliamentary impeachment dec waiting constitutional court rule formally removed office reinstated north korea conduct test coming month test trump administration year increasingly harsh sanction north korea advancing kim professed goal arming isolated country ability deliver nuclear warhead united state kim speech sunday north korea rocket time year complete icbm program cheong senior research fellow sejong institute south korea test trump inauguration cheong note fact year speech kim mentioned intercontinental ballistic missile speech kim comment trump election doubt run deep north korea mastered technology needed build reliable icbm analyst region north launching rocket put satellite orbit recent year showed country cleared key technological hurdle north satellite launch february south korean defense official unha rocket launch successfully reconfigured missile fly mile warhead pound reach united state north korea deployed rodong ballistic missile reach south korea japan spotty record musudan ballistic missile range long reach american military base pacific including guam north claimed series success testing icbm technology claim verified disputed official analyst region make nuclear warhead small fit ballistic missile claimed success testing technology missile return earth atmosphere breaking april north korea reported successful ground test engine intercontinental ballistic missile time kim north tip intercontinental ballistic rocket powerful nuclear warhead cesspool evil earth including mainland striking range sept north conducted powerful nuclear test kim attended ground test rocket engine exhorting government prepare rocket launch november united nation security council imposed sanction north']

# %%
corpus_list = []

for i in range(len(corpus)):
    tokened_article = corpus[i].split()
    corpus_list.append(tokened_article)

corpus_list[:5]
# Out:
# [['washington',
#   'congressional',
#   'republican',
#   'fear',
#   'health',
#   'care',
#   'lawsuit',
#   'obama',
#   'administration',
#   'win',
#   'incoming',
#   'trump',
#   'administration',
#   'choose',
#   'longer',
#   'defend',
#   'executive',
#   'branch',
#   'suit',
#   'challenge',
#   'administration',
#   'authority',
#   'spend',
#   'billion',
#   'dollar',
#   'health',
#   'insurance',
#   'subsidy',
#   'american',
#   'handing',
#   'house',
#   'republican',
#   'big',
#   'victory',
#   'issue',
#   'sudden',
#   'loss',
#   'disputed',
#   'subsidy',
#   'conceivably',
#   'health',
#   'care',
#   'program',
#   'implode',
#   'leaving',
#   'million',
#   'people',
#   'access',
#   'health',
#   'insurance',
#   'republican',
#   'prepared',
#   'replacement',
#   'lead',
#   'chaos',
#   'insurance',
#   'market',
#   'spur',
#   'political',
#   'backlash',
#   'republican',
#   'gain',
#   'full',
#   'control',
#   'government',
#   'stave',
#   'outcome',
#   'republican',
#   'find',
#   'awkward',
#   'position',
#   'appropriating',
#   'huge',
#   'sum',
#   'temporarily',
#   'prop',
#   'obama',
#   'health',
#   'care',
#   'law',
#   'angering',
#   'conservative',
#   'voter',
#   'demanding',
#   'end',
#   'law',
#   'year',
#   'twist',
#   'donald',
#   'trump',
#   'administration',
#   'worried',
#   'preserving',
#   'executive',
#   'branch',
#   'prerogative',
#   'choose',
#   'fight',
#   'republican',
#   'ally',
#   'house',
#   'central',
#   'question',
#   'dispute',
#   'eager',
#   'avoid',
#   'ugly',
#   'political',
#   'pileup',
#   'republican',
#   'capitol',
#   'hill',
#   'trump',
#   'transition',
#   'team',
#   'gaming',
#   'handle',
#   'lawsuit',
#   'election',
#   'put',
#   'limbo',
#   'late',
#   'february',
#   'united',
#   'state',
#   'court',
#   'appeal',
#   'district',
#   'columbia',
#   'circuit',
#   'ready',
#   'divulge',
#   'strategy',
#   'pending',
#   'litigation',
#   'involves',
#   'obama',
#   'administration',
#   'congress',
#   'inappropriate',
#   'comment',
#   'phillip',
#   'blando',
#   'spokesman',
#   'trump',
#   'transition',
#   'effort',
#   'taking',
#   'office',
#   'trump',
#   'administration',
#   'evaluate',
#   'case',
#   'related',
#   'aspect',
#   'affordable',
#   'care',
#   'act',
#   'potentially',
#   'decision',
#   'judge',
#   'rosemary',
#   'collyer',
#   'ruled',
#   'house',
#   'republican',
#   'standing',
#   'sue',
#   'executive',
#   'branch',
#   'spending',
#   'dispute',
#   'obama',
#   'administration',
#   'distributing',
#   'health',
#   'insurance',
#   'subsidy',
#   'violation',
#   'constitution',
#   'approval',
#   'congress',
#   'justice',
#   'department',
#   'confident',
#   'judge',
#   'collyer',
#   'decision',
#   'reversed',
#   'quickly',
#   'appealed',
#   'subsidy',
#   'remained',
#   'place',
#   'appeal',
#   'successfully',
#   'seeking',
#   'temporary',
#   'halt',
#   'proceeding',
#   'trump',
#   'won',
#   'house',
#   'republican',
#   'month',
#   'told',
#   'court',
#   'transition',
#   'team',
#   'discussing',
#   'potential',
#   'option',
#   'resolution',
#   'matter',
#   'effect',
#   'inauguration',
#   'jan',
#   'suspension',
#   'case',
#   'house',
#   'lawyer',
#   'provide',
#   'future',
#   'administration',
#   'time',
#   'continue',
#   'prosecuting',
#   'resolve',
#   'appeal',
#   'republican',
#   'leadership',
#   'official',
#   'house',
#   'acknowledge',
#   'possibility',
#   'cascading',
#   'effect',
#   'payment',
#   'totaled',
#   'estimated',
#   'billion',
#   'suddenly',
#   'stopped',
#   'insurer',
#   'receive',
#   'subsidy',
#   'exchange',
#   'paying',
#   'cost',
#   'deductible',
#   'eligible',
#   'consumer',
#   'race',
#   'drop',
#   'coverage',
#   'losing',
#   'money',
#   'loss',
#   'subsidy',
#   'destabilize',
#   'entire',
#   'program',
#   'lack',
#   'confidence',
#   'lead',
#   'insurer',
#   'seek',
#   'quick',
#   'exit',
#   'anticipating',
#   'trump',
#   'administration',
#   'inclined',
#   'mount',
#   'vigorous',
#   'fight',
#   'house',
#   'republican',
#   'dim',
#   'view',
#   'health',
#   'care',
#   'law',
#   'team',
#   'lawyer',
#   'month',
#   'sought',
#   'intervene',
#   'case',
#   'behalf',
#   'participant',
#   'health',
#   'care',
#   'program',
#   'request',
#   'lawyer',
#   'predicted',
#   'deal',
#   'house',
#   'republican',
#   'administration',
#   'dismiss',
#   'settle',
#   'case',
#   'produce',
#   'devastating',
#   'consequence',
#   'individual',
#   'receive',
#   'reduction',
#   'nation',
#   'health',
#   'insurance',
#   'health',
#   'care',
#   'system',
#   'generally',
#   'matter',
#   'house',
#   'republican',
#   'prevail',
#   'overarching',
#   'concept',
#   'congressional',
#   'power',
#   'purse',
#   'congress',
#   'sue',
#   'executive',
#   'branch',
#   'violates',
#   'constitution',
#   'spending',
#   'power',
#   'house',
#   'republican',
#   'contend',
#   'congress',
#   'appropriated',
#   'money',
#   'subsidy',
#   'required',
#   'constitution',
#   'suit',
#   'initially',
#   'championed',
#   'john',
#   'boehner',
#   'house',
#   'speaker',
#   'time',
#   'house',
#   'committee',
#   'report',
#   'republican',
#   'asserted',
#   'administration',
#   'desperate',
#   'funding',
#   'required',
#   'treasury',
#   'department',
#   'provide',
#   'widespread',
#   'internal',
#   'skepticism',
#   'spending',
#   'proper',
#   'white',
#   'house',
#   'spending',
#   'permanent',
#   'part',
#   'law',
#   'passed',
#   'annual',
#   'appropriation',
#   'required',
#   'administration',
#   'initially',
#   'sought',
#   'important',
#   'house',
#   'republican',
#   'judge',
#   'collyer',
#   'found',
#   'congress',
#   'standing',
#   'sue',
#   'white',
#   'house',
#   'issue',
#   'ruling',
#   'legal',
#   'expert',
#   'flawed',
#   'precedent',
#   'set',
#   'restore',
#   'congressional',
#   'leverage',
#   'executive',
#   'branch',
#   'spending',
#   'power',
#   'standing',
#   'trump',
#   'administration',
#   'pressure',
#   'advocate',
#   'presidential',
#   'authority',
#   'fight',
#   'house',
#   'matter',
#   'shared',
#   'view',
#   'health',
#   'care',
#   'precedent',
#   'broad',
#   'repercussion',
#   'complicated',
#   'set',
#   'dynamic',
#   'illustrating',
#   'quick',
#   'legal',
#   'victory',
#   'house',
#   'trump',
#   'era',
#   'cost',
#   'republican',
#   'anticipated',
#   'obama',
#   'white',
#   'house'],
#  ['bullet',
#   'shell',
#   'counted',
#   'blood',
#   'dry',
#   'votive',
#   'candle',
#   'burn',
#   'people',
#   'peer',
#   'window',
#   'crime',
#   'scene',
#   'cold',
#   'band',
#   'yellow',
#   'police',
#   'tape',
#   'blowing',
#   'breeze',
#   'south',
#   'bronx',
#   'harlem',
#   'river',
#   'manhattan',
#   'shorthand',
#   'urban',
#   'dysfunction',
#   'suffers',
#   'violence',
#   'level',
#   'long',
#   'ago',
#   'slashed',
#   'part',
#   'york',
#   'city',
#   'city',
#   'effort',
#   'fight',
#   'remain',
#   'splintered',
#   'underfunded',
#   'burdened',
#   'scandal',
#   'precinct',
#   'southern',
#   'tip',
#   'bronx',
#   'poor',
#   'minority',
#   'neighborhood',
#   'country',
#   'people',
#   'long',
#   'hounded',
#   'infraction',
#   'cry',
#   'protection',
#   'grievous',
#   'injury',
#   'death',
#   'september',
#   'shooting',
#   'precinct',
#   'year',
#   'unsolved',
#   'city',
#   'precinct',
#   'highest',
#   'murder',
#   'rate',
#   'fewest',
#   'detective',
#   'violent',
#   'crime',
#   'reflecting',
#   'disparity',
#   'staffing',
#   'hit',
#   'hardest',
#   'neighborhood',
#   'manhattan',
#   'york',
#   'time',
#   'analysis',
#   'police',
#   'department',
#   'data',
#   'investigator',
#   'precinct',
#   'saddled',
#   'number',
#   'case',
#   'department',
#   'recommends',
#   'boss',
#   'called',
#   'police',
#   'headquarters',
#   'answer',
#   'sharpest',
#   'crime',
#   'rise',
#   'city',
#   'year',
#   'bronx',
#   'investigative',
#   'resource',
#   'squeezed',
#   'highest',
#   'rate',
#   'city',
#   'borough',
#   'thinnest',
#   'detective',
#   'staffing',
#   'precinct',
#   'detective',
#   'squad',
#   'violent',
#   'crime',
#   'city',
#   'borough',
#   'robbery',
#   'squad',
#   'smaller',
#   'manhattan',
#   'bronx',
#   'case',
#   'year',
#   'homicide',
#   'squad',
#   'detective',
#   'murder',
#   'compared',
#   'detective',
#   'roughly',
#   'murder',
#   'upper',
#   'manhattan',
#   'detective',
#   'murder',
#   'lower',
#   'manhattan',
#   'lobby',
#   'family',
#   'apartment',
#   'methadone',
#   'clinic',
#   'art',
#   'studio',
#   'people',
#   'note',
#   'inequity',
#   'hear',
#   'police',
#   'commander',
#   'explain',
#   'lack',
#   'resource',
#   'place',
#   'floodlight',
#   'dangerous',
#   'block',
#   'post',
#   'officer',
#   'corner',
#   'watch',
#   'witness',
#   'cower',
#   'door',
#   'fearful',
#   'gunman',
#   'crew',
#   'confident',
#   'police',
#   'department',
#   'ability',
#   'protect',
#   'people',
#   'lot',
#   'rarely',
#   'testify',
#   'south',
#   'bronx',
#   'predominantly',
#   'black',
#   'hispanic',
#   'neighborhood',
#   'united',
#   'state',
#   'contract',
#   'police',
#   'community',
#   'tatter',
#   'people',
#   'story',
#   'crime',
#   'report',
#   'call',
#   'unanswered',
#   'hour',
#   'call',
#   'ending',
#   'caller',
#   'arrest',
#   'minor',
#   'charge',
#   'leading',
#   'hour',
#   'fetid',
#   'holding',
#   'cell',
#   'paradox',
#   'policing',
#   'precinct',
#   'neighborhood',
#   'historically',
#   'prime',
#   'target',
#   'aggressive',
#   'tactic',
#   'designed',
#   'ward',
#   'disorder',
#   'precinct',
#   'detective',
#   'time',
#   'city',
#   'answer',
#   'blood',
#   'spilled',
#   'violent',
#   'crime',
#   'gola',
#   'white',
#   'daughter',
#   'shot',
#   'killed',
#   'playground',
#   'summer',
#   'year',
#   'son',
#   'gunned',
#   'housing',
#   'project',
#   'ticked',
#   'public',
#   'safety',
#   'resource',
#   'scant',
#   'bronx',
#   'neighborhood',
#   'security',
#   'camera',
#   'light',
#   'lock',
#   'investigating',
#   'police',
#   'officer',
#   'family',
#   'authority',
#   'don',
#   'care',
#   'feel',
#   'time',
#   'documenting',
#   'murder',
#   'logged',
#   'year',
#   'precinct',
#   'handful',
#   'neighborhood',
#   'deadly',
#   'violence',
#   'remains',
#   'problem',
#   'era',
#   'crime',
#   'york',
#   'city',
#   'homicide',
#   'precinct',
#   'year',
#   'strain',
#   'detective',
#   'unsolved',
#   'half',
#   'year',
#   'law',
#   'hand',
#   'hundred',
#   'conversation',
#   'grieving',
#   'relative',
#   'friend',
#   'witness',
#   'police',
#   'officer',
#   'social',
#   'force',
#   'flare',
#   'murder',
#   'place',
#   'precinct',
#   'clearer',
#   'merciless',
#   'gang',
#   'code',
#   'mental',
#   'illness',
#   'drug',
#   'long',
#   'memory',
#   'feud',
#   'simmered',
#   'officer',
#   'view',
#   'reason',
#   'murder',
#   'solved',
#   'emerge',
#   'paralyzing',
#   'fear',
#   'retribution',
#   'victim',
#   'carrying',
#   'secret',
#   'graf',
#   'relentless',
#   'casework',
#   'force',
#   'detective',
#   'move',
#   'hope',
#   'break',
#   'frustration',
#   'build',
#   'side',
#   'detective',
#   'phone',
#   'rarely',
#   'ring',
#   'tip',
#   'officer',
#   'grow',
#   'embittered',
#   'witness',
#   'cooperate',
#   'meantime',
#   'victim',
#   'friend',
#   'conduct',
#   'investigation',
#   'talk',
#   'grabbing',
#   'stash',
#   'gun',
#   'wheel',
#   'mother',
#   'apartment',
#   'find',
#   'suspect',
#   'chasm',
#   'police',
#   'community',
#   'gang',
#   'gun',
#   'violence',
#   'flourish',
#   'parent',
#   'protect',
#   'family',
#   'drug',
#   'crew',
#   'threat',
#   'officer',
#   'work',
#   'overcome',
#   'residue',
#   'year',
#   'mistrust',
#   'understaffing',
#   'community',
#   'racing',
#   'call',
#   'street',
#   'st',
#   'mary',
#   'park',
#   'scene',
#   'fatal',
#   'shooting',
#   'logged',
#   'precinct',
#   'year',
#   'unsolved',
#   'james',
#   'fernandez',
#   'heard',
#   'talk',
#   'murder',
#   'door',
#   'apartment',
#   'east',
#   'street',
#   'betances',
#   'house',
#   'lived',
#   'end',
#   'long',
#   'hallway',
#   'strewn',
#   'hypodermic',
#   'needle',
#   'empty',
#   'dope',
#   'bag',
#   'discarded',
#   'hennessy',
#   'bottle',
#   'young',
#   'men',
#   'spoke',
#   'subset',
#   'blood',
#   'gang',
#   'made',
#   'drug',
#   'market',
#   'slinging',
#   'marijuana',
#   'cocaine',
#   'regular',
#   'flashing',
#   'firearm',
#   'blowing',
#   'smoke',
#   'fernandez',
#   'apartment',
#   'fernandez',
#   'asked',
#   'young',
#   'men',
#   'move',
#   'answered',
#   'busting',
#   'car',
#   'kind',
#   'crime',
#   'anachronism',
#   'york',
#   'rattle',
#   'precinct',
#   'murder',
#   'fallen',
#   'year',
#   'major',
#   'felony',
#   'crime',
#   'resident',
#   'residential',
#   'district',
#   'city',
#   'poorest',
#   'community',
#   'country',
#   'young',
#   'men',
#   'find',
#   'underground',
#   'market',
#   'fernandez',
#   'shrink',
#   'threat',
#   'growing',
#   'lower',
#   'east',
#   'side',
#   'rode',
#   'bicycle',
#   'customer',
#   'drug',
#   'dealer',
#   'worked',
#   'collected',
#   'payment',
#   'backpack',
#   'leaving',
#   'life',
#   'tech',
#   'maintenance',
#   'job',
#   'year',
#   'ago',
#   'moved',
#   'betances',
#   'house',
#   'wife',
#   'daughter',
#   'choice',
#   'drug',
#   'crew',
#   'call',
#   'police',
#   'risk',
#   'labeled',
#   'snitch',
#   'call',
#   'lower',
#   'east',
#   'side',
#   'boss',
#   'muscle',
#   'risk',
#   'violence',
#   'chose',
#   'police',
#   'walked',
#   'local',
#   'substation',
#   'police',
#   'service',
#   'area',
#   'asked',
#   'protection',
#   'daughter',
#   'inhaler',
#   'relieve',
#   'cough',
#   'marijuana',
#   'smoke',
#   'fernandez',
#   'wife',
#   'terrible',
#   'headache',
#   'lot',
#   'killer',
#   'kill',
#   'sergeant',
#   'police',
#   'report',
#   'quoted',
#   'telling',
#   'fernandez',
#   'august',
#   'report',
#   'filed',
#   'day',
#   'warned',
#   'shoot',
#   'window',
#   'fernandez',
#   'told',
#   'police',
#   'teenager',
#   'name',
#   'report',
#   'home',
#   'friend',
#   'walk',
#   'substation',
#   'intimidate',
#   'filing',
#   'report',
#   'day',
#   'propped',
#   'bike',
#   'door',
#   'open',
#   'door',
#   'body',
#   'slam',
#   'fernandez',
#   'wife',
#   'maria',
#   'fernandez',
#   'wrote',
#   'slip',
#   'paper',
#   'document',
#   'hallway',
#   'ruckus',
#   'inadequate',
#   'police',
#   'response',
#   'boy',
#   'made',
#   'comment',
#   'easy',
#   'target',
#   'slap',
#   'opened',
#   'door',
#   'made',
#   'drug',
#   'sale',
#   'threatened',
#   'beat',
#   'fernandez',
#   'family',
#   'snitching',
#   'note',
#   'complaint',
#   'substation',
#   'day',
#   'brought',
#   'relief',
#   'week',
#   'feeling',
#   'desperate',
#   'm',
#   'fernandez',
#   'calling',
#   'substation',
#   'boy',
#   'blew',
#   'weed',
#   'smoke',
#   'door',
#   'made',
#   'threat',
#   'attack',
#   'police',
#   'wrote',
#   'note',
#   'precinct',
#   'station',
#   'house',
#   'officer',
#   'desk',
#   'left',
#   'standing',
#   'public',
#   'waiting',
#   'area',
#   'making',
#   'fear',
#   'officer',
#   'put',
#   'worse',
#   'danger',
#   'month',
#   'door',
#   'announced',
#   'front',
#   'teenager',
#   'complaint',
#   'drug',
#   'activity',
#   'fernandez',
#   'started',
#   'work',
#   'police',
#   'failed',
#   'wired',
#   'camera',
#   'peephole',
#   'record',
#   'drug',
#   'gun',
#   'footage',
#   'hark',
#   'back',
#   'york',
#   'present',
#   'precinct',
#   'resident',
#   'morning',
#   'sgt',
#   'michael',
#   'lopuzzo',
#   'walk',
#   'tall',
#   'wooden',
#   'door',
#   'precinct',
#   'station',
#   'house',
#   'case',
#   'land',
#   'metal',
#   'desk',
#   'dead',
#   'body',
#   'strip',
#   'club',
#   'brawl',
#   'shooting',
#   'victim',
#   'hobbling',
#   'hospital',
#   'bring',
#   'resistance',
#   'turn',
#   'reminding',
#   'earlier',
#   'era',
#   'city',
#   'campaign',
#   'haven',
#   'single',
#   'phone',
#   'call',
#   'putting',
#   'direction',
#   'sergeant',
#   'lopuzzo',
#   'head',
#   'precinct',
#   'detective',
#   'squad',
#   'day',
#   'summer',
#   'worked',
#   'answer',
#   'email',
#   'inquiry',
#   'murder',
#   'victim',
#   'aunt',
#   'killer',
#   'caught',
#   'people',
#   'don',
#   'understand',
#   'detective',
#   'feel',
#   'effect',
#   'people',
#   'turning',
#   'police',
#   'witness',
#   'shout',
#   'door',
#   'neighbor',
#   'refuse',
#   'talk',
#   'people',
#   'shot',
#   'wounded',
#   'bronx',
#   'early',
#   'september',
#   'victim',
#   'refused',
#   'cooperate',
#   'period',
#   'precinct',
#   'squad',
#   'detective',
#   'closed',
#   'nonfatal',
#   'shooting',
#   'robbery',
#   'case',
#   'part',
#   'resistance',
#   'stem',
#   'preventive',
#   'policing',
#   'tactic',
#   'hallmark',
#   'style',
#   'mayor',
#   'michael',
#   'bloomberg',
#   'police',
#   'commissioner',
#   'raymond',
#   'kelly',
#   'height',
#   'strategy',
#   'precinct',
#   'stop',
#   'city',
#   'stop',
#   'officer',
#   'force',
#   'frisk',
#   'stop',
#   'year',
#   'people',
#   'criminal',
#   'precinct',
#   'area',
#   'department',
#   'flooded',
#   'newest',
#   'officer',
#   'roll',
#   'call',
#   'pressured',
#   'generate',
#   'number',
#   'write',
#   'ticket',
#   'make',
#   'arrest',
#   'choice',
#   'give',
#   'summons',
#   'young',
#   'man',
#   'playing',
#   'park',
#   'dark',
#   'officer',
#   'growing',
#   'neighborhood',
#   'bring',
#   'today',
#   'justify',
#   'existence',
#   'officer',
#   'argenis',
#   'rosado',
#   'joined',
#   'precinct',
#   'interview',
#   'station',
#   'house',
#   'small',
#   'area',
#   'day',
#   'day',
#   'hammering',
#   'community',
#   'community',
#   'eventually',
#   'turn',
#   'pressure',
#   'warped',
#   'officer',
#   'resident',
#   'rookie',
#   'ignore',
#   'drinking',
#   'sitting',
#   'stoop',
#   'cop',
#   'time',
#   'viewed',
#   'community',
#   'differently',
#   'hector',
#   'espada',
#   'veteran',
#   'precinct',
#   'wanted',
#   'give',
#   'summons',
#   'feel',
#   'guy',
#   'civil',
#   'conversation',
#   'morale',
#   'wilted',
#   'aged',
#   'station',
#   'house',
#   'alexander',
#   'avenue',
#   'mott',
#   'haven',
#   'officer',
#   'felt',
#   'pressure',
#   'downgrade',
#   'crime',
#   'complaint',
#   'make',
#   'interview',
#   'overlooked',
#   'crime',
#   'report',
#   'immigrant',
#   'complain',
#   'watched',
#   'supervisor',
#   'badger',
#   'victim',
#   'repeating',
#   'story',
#   'hope',
#   'drop',
#   'complaint',
#   'practice',
#   'downgrading',
#   'complaint',
#   'resulted',
#   'disciplining',
#   'officer',
#   'precinct',
#   'year',
#   'string',
#   'scandal',
#   'left',
#   'officer',
#   'feeling',
#   'overscrutinized',
#   'problem',
#   'existed',
#   'commander',
#   'precinct',
#   'packing',
#   'year',
#   'officer',
#   'found',
#   'ticket',
#   'fixing',
#   'forgiving',
#   'parking',
#   'ticket',
#   'friend',
#   'recorded',
#   'giving',
#   'guidance',
#   'stop',
#   'frisk',
#   'black',
#   'boy',
#   'men',
#   'age',
#   'officer',
#   'fled',
#   'command',
#   'reluctant',
#   'assignment',
#   'proactive',
#   'policing',
#   'unit',
#   'put',
#   'situation',
#   'street',
#   'walked',
#   'door',
#   'precinct',
#   'black',
#   'cloud',
#   'russell',
#   'lewis',
#   'heaviness',
#   'walked',
#   'wanted',
#   'hour',
#   'minute',
#   'home',
#   'didn',
#   'caught',
#   'precinct',
#   'cover',
#   'square',
#   'mile',
#   'dozen',
#   'housing',
#   'project',
#   'overflow',
#   'people',
#   'methadone',
#   'clinic',
#   'draw',
#   'addict',
#   'city',
#   'loft',
#   'southern',
#   'edge',
#   'precinct',
#   'presage',
#   'wave',
#   'gentrification',
#   'police',
#   'department',
#   'hired',
#   'officer',
#   'neighborhood',
#   'policing',
#   'counterterrorism',
#   'officer',
#   'precinct',
#   'rush',
#   'call',
#   'shift',
#   'number',
#   'unchanged',
#   'police',
#   'commissioner',
#   'james',
#   'neill',
#   'handling',
#   'similar',
#   'south',
#   'bronx',
#   'precinct',
#   'year',
#   'ago',
#   'dozen',
#   'call',
#   'time',
#   ...],
#  ['walt',
#   'disney',
#   'bambi',
#   'opened',
#   'critic',
#   'praised',
#   'spare',
#   'haunting',
#   'visual',
#   'style',
#   'vastly',
#   'disney',
#   'film',
#   'striking',
#   'appearance',
#   'created',
#   'chinese',
#   'immigrant',
#   'artist',
#   'inspiration',
#   'landscape',
#   'painting',
#   'song',
#   'dynasty',
#   'extent',
#   'contribution',
#   'bambi',
#   'remains',
#   'mark',
#   'film',
#   'animation',
#   'widely',
#   'decade',
#   'film',
#   'title',
#   'character',
#   'artist',
#   'tyrus',
#   'wong',
#   'weathered',
#   'irrevocable',
#   'separation',
#   'mother',
#   'hope',
#   'making',
#   'life',
#   'america',
#   'incarceration',
#   'isolation',
#   'rigorous',
#   'interrogation',
#   'child',
#   'year',
#   'endured',
#   'poverty',
#   'discrimination',
#   'chronic',
#   'lack',
#   'recognition',
#   'work',
#   'disney',
#   'fine',
#   'art',
#   'finding',
#   'acclaim',
#   'wong',
#   'died',
#   'friday',
#   'hollywood',
#   'studio',
#   'artist',
#   'painter',
#   'printmaker',
#   'calligrapher',
#   'illustrator',
#   'year',
#   'maker',
#   'fantastical',
#   'kite',
#   'celebrated',
#   'artist',
#   'century',
#   'marginalization',
#   'long',
#   'subject',
#   'passed',
#   'career',
#   'unknown',
#   'general',
#   'public',
#   'artistic',
#   'recognition',
#   'wong',
#   'find',
#   'noteworthy',
#   'fact',
#   'chinese',
#   'immigrant',
#   'men',
#   'generation',
#   'professional',
#   'prospect',
#   'largely',
#   'limited',
#   'menial',
#   'job',
#   'houseboy',
#   'laundryman',
#   'trained',
#   'painter',
#   'wong',
#   'leading',
#   'figure',
#   'modernist',
#   'movement',
#   'flourished',
#   'california',
#   'world',
#   'war',
#   'work',
#   'included',
#   'group',
#   'show',
#   'art',
#   'institute',
#   'chicago',
#   'featured',
#   'picasso',
#   'matisse',
#   'paul',
#   'klee',
#   'staff',
#   'artist',
#   'hollywood',
#   'studio',
#   'drew',
#   'storyboards',
#   'made',
#   'vibrant',
#   'painting',
#   'detailed',
#   'architectural',
#   'illustration',
#   'helped',
#   'director',
#   'envision',
#   'scene',
#   'shot',
#   'year',
#   'work',
#   'informed',
#   'animated',
#   'picture',
#   'disney',
#   'film',
#   'warner',
#   'brother',
#   'studio',
#   'sand',
#   'iwo',
#   'jima',
#   'rebel',
#   'wild',
#   'bunch',
#   'dozen',
#   'film',
#   'worked',
#   'bambi',
#   'wong',
#   'belatedly',
#   'renowned',
#   'involved',
#   'phase',
#   'production',
#   'john',
#   'canemaker',
#   'animator',
#   'historian',
#   'animation',
#   'york',
#   'university',
#   'interview',
#   'obituary',
#   'march',
#   'created',
#   'art',
#   'direction',
#   'animation',
#   'wong',
#   'subject',
#   'water',
#   'paper',
#   'paint',
#   'sky',
#   'major',
#   'retrospective',
#   'disney',
#   'family',
#   'museum',
#   'san',
#   'francisco',
#   'museum',
#   'window',
#   'overlook',
#   'san',
#   'francisco',
#   'bay',
#   'contemplate',
#   'angel',
#   'island',
#   'decade',
#   'earlier',
#   'lone',
#   'sought',
#   'gain',
#   'admission',
#   'country',
#   'adamantly',
#   'wong',
#   'gen',
#   'yeo',
#   'romanized',
#   'wong',
#   'gaing',
#   'yoo',
#   'born',
#   'oct',
#   'farming',
#   'village',
#   'guangdong',
#   'province',
#   'young',
#   'child',
#   'exhibited',
#   'love',
#   'drawing',
#   'encouraged',
#   'father',
#   'seeking',
#   'economic',
#   'prospect',
#   'gen',
#   'yeo',
#   'father',
#   'embarked',
#   'united',
#   'state',
#   'leaving',
#   'mother',
#   'sister',
#   'gen',
#   'yeo',
#   'mother',
#   'obliged',
#   'travel',
#   'false',
#   'identity',
#   'state',
#   'affair',
#   'chinese',
#   'immigrant',
#   'paper',
#   'son',
#   'hope',
#   'circumventing',
#   'chinese',
#   'exclusion',
#   'act',
#   'signed',
#   'law',
#   'president',
#   'chester',
#   'arthur',
#   'act',
#   'drastically',
#   'curtailed',
#   'number',
#   'chinese',
#   'people',
#   'allowed',
#   'enter',
#   'country',
#   'earliest',
#   'united',
#   'state',
#   'law',
#   'impose',
#   'severe',
#   'restriction',
#   'immigration',
#   'unforeseen',
#   'loophole',
#   'opened',
#   'form',
#   'san',
#   'francisco',
#   'earthquake',
#   'fire',
#   'huge',
#   'number',
#   'municipal',
#   'document',
#   'including',
#   'birth',
#   'immigration',
#   'record',
#   'destroyed',
#   'newly',
#   'arrived',
#   'chinese',
#   'capitalized',
#   'loss',
#   'maintaining',
#   'born',
#   'san',
#   'francisco',
#   'fire',
#   'united',
#   'state',
#   'citizen',
#   'entitled',
#   'bring',
#   'relative',
#   'case',
#   'gen',
#   'yeo',
#   'father',
#   'paper',
#   'son',
#   'posing',
#   'relative',
#   'attuned',
#   'deception',
#   'united',
#   'state',
#   'immigration',
#   'official',
#   'put',
#   'chinese',
#   'arrival',
#   'formidable',
#   'inquisition',
#   'ensure',
#   'claimed',
#   'question',
#   'gunfire',
#   'direction',
#   'village',
#   'face',
#   'window',
#   'house',
#   'house',
#   'rice',
#   'bin',
#   'wide',
#   'deep',
#   'tree',
#   'village',
#   'lake',
#   'shop',
#   'sponsoring',
#   'relative',
#   'interrogated',
#   'separately',
#   'answer',
#   'match',
#   'arrival',
#   'major',
#   'mistake',
#   'series',
#   'smaller',
#   'deportation',
#   'stand',
#   'chance',
#   'passing',
#   'aspirant',
#   'memorized',
#   'rigorous',
#   'dossier',
#   'coaching',
#   'paper',
#   'ensuing',
#   'interrogation',
#   'hard',
#   'adult',
#   'gen',
#   'yeo',
#   'undergo',
#   'dec',
#   'month',
#   'sea',
#   'wongs',
#   'landed',
#   'angel',
#   'island',
#   'immigration',
#   'station',
#   'elder',
#   'wong',
#   'traveling',
#   'merchant',
#   'named',
#   'son',
#   'tai',
#   'yow',
#   'angel',
#   'island',
#   'considered',
#   'elli',
#   'island',
#   'west',
#   'coast',
#   'lisa',
#   'author',
#   'gold',
#   'mountain',
#   'nonfiction',
#   'chronicle',
#   'family',
#   'interview',
#   'continued',
#   'goal',
#   'elli',
#   'island',
#   'supposed',
#   'welcoming',
#   'angel',
#   'island',
#   'opened',
#   'specifically',
#   'chinese',
#   'wong',
#   'father',
#   'previously',
#   'lived',
#   'united',
#   'state',
#   'clear',
#   'immigration',
#   'quickly',
#   'arrival',
#   'gen',
#   'yeo',
#   'detained',
#   'island',
#   'month',
#   'child',
#   'immigrant',
#   'held',
#   'scared',
#   'half',
#   'death',
#   'cried',
#   'wong',
#   'recalled',
#   'tyrus',
#   'documentary',
#   'directed',
#   'pamela',
#   'tom',
#   'premiered',
#   'day',
#   'miserable',
#   'miserable',
#   'hated',
#   'place',
#   'jan',
#   'presence',
#   'interpreter',
#   'stenographer',
#   'young',
#   'gen',
#   'yeo',
#   'posing',
#   'tai',
#   'yow',
#   'interrogated',
#   'inspector',
#   'father',
#   'questioned',
#   'gen',
#   'yeo',
#   'prepared',
#   'answered',
#   'error',
#   'sacramento',
#   'joined',
#   'father',
#   'schoolteacher',
#   'americanized',
#   'tai',
#   'yow',
#   'tyrus',
#   'tyrus',
#   'wong',
#   'afterward',
#   'father',
#   'son',
#   'separated',
#   'elder',
#   'wong',
#   'moved',
#   'los',
#   'angeles',
#   'seek',
#   'work',
#   'reason',
#   'lost',
#   'time',
#   'son',
#   'tyrus',
#   'lived',
#   'sacramento',
#   'boardinghouse',
#   'attending',
#   'elementary',
#   'school',
#   'year',
#   'possibly',
#   'tyrus',
#   'traveled',
#   'los',
#   'angeles',
#   'join',
#   'father',
#   'found',
#   'work',
#   'gambling',
#   'den',
#   'lived',
#   'boardinghouse',
#   'sandwiched',
#   'butcher',
#   'shop',
#   'brothel',
#   'school',
#   'tyrus',
#   'worked',
#   'houseboy',
#   'pasadena',
#   'family',
#   'earning',
#   'cent',
#   'day',
#   'art',
#   'teacher',
#   'father',
#   'trained',
#   'nightly',
#   'calligraphy',
#   'dip',
#   'brush',
#   'water',
#   'trace',
#   'ghostly',
#   'character',
#   'newspaper',
#   'afford',
#   'ink',
#   'drawing',
#   'paper',
#   'tyrus',
#   'junior',
#   'high',
#   'teacher',
#   'noting',
#   'drawing',
#   'talent',
#   'arranged',
#   'summer',
#   'scholarship',
#   'otis',
#   'art',
#   'institute',
#   'los',
#   'angeles',
#   'account',
#   'indifferent',
#   'student',
#   'public',
#   'school',
#   'tyrus',
#   'found',
#   'calling',
#   'institute',
#   'otis',
#   'college',
#   'art',
#   'design',
#   'scholarship',
#   'ended',
#   'declined',
#   'return',
#   'junior',
#   'high',
#   'father',
#   'scraped',
#   'tuition',
#   'small',
#   'fortune',
#   'stay',
#   'otis',
#   'youngest',
#   'student',
#   'studied',
#   'year',
#   'simultaneously',
#   'working',
#   'school',
#   'janitor',
#   'graduating',
#   'long',
#   'afterward',
#   'father',
#   'died',
#   'leaving',
#   'young',
#   'wong',
#   'wong',
#   'artist',
#   'work',
#   'progress',
#   'administration',
#   'creating',
#   'painting',
#   'library',
#   'public',
#   'space',
#   'friend',
#   'including',
#   'artist',
#   'benji',
#   'okubo',
#   'founded',
#   'oriental',
#   'artist',
#   'group',
#   'los',
#   'angeles',
#   'organized',
#   'exhibition',
#   'member',
#   'work',
#   'level',
#   'exposure',
#   'asian',
#   'artist',
#   'time',
#   'wong',
#   'newly',
#   'married',
#   'needing',
#   'steady',
#   'work',
#   'joined',
#   'disney',
#   'creating',
#   'thousand',
#   'intermediate',
#   'drawing',
#   'bring',
#   'animated',
#   'sequence',
#   'life',
#   'asian',
#   'novelty',
#   'hollywood',
#   'studio',
#   'wong',
#   'made',
#   'keenly',
#   'aware',
#   'fact',
#   'disney',
#   'warner',
#   'brother',
#   'flung',
#   'racial',
#   'epithet',
#   'assumed',
#   'sight',
#   'worked',
#   'company',
#   'cafeteria',
#   'affront',
#   'job',
#   'painstaking',
#   'repetitive',
#   'wong',
#   'quickly',
#   'work',
#   'animation',
#   'terrible',
#   'talent',
#   'landscape',
#   'artist',
#   'painter',
#   'canemaker',
#   'reprieve',
#   'late',
#   'wong',
#   'learned',
#   'disney',
#   'adapting',
#   'bambi',
#   'life',
#   'wood',
#   'austrian',
#   'writer',
#   'felix',
#   'salten',
#   'fawn',
#   'mother',
#   'killed',
#   'hunter',
#   'animate',
#   'book',
#   'disney',
#   'reached',
#   'impasse',
#   'studio',
#   'enjoyed',
#   'great',
#   'success',
#   'animated',
#   'film',
#   'snow',
#   'white',
#   'dwarf',
#   'baroque',
#   'production',
#   'detail',
#   'background',
#   'petal',
#   'flower',
#   'leaf',
#   'tree',
#   'meticulously',
#   'represented',
#   'attempt',
#   'similar',
#   'style',
#   'bambi',
#   'found',
#   'ornate',
#   'background',
#   'camouflaged',
#   'deer',
#   'forest',
#   'creature',
#   'narrative',
#   'centered',
#   'wong',
#   'spied',
#   'chance',
#   'gee',
#   'outdoor',
#   'scenery',
#   'recalled',
#   'video',
#   'interview',
#   'year',
#   'afterward',
#   'adding',
#   'gee',
#   'landscape',
#   'painter',
#   'invoking',
#   'exquisite',
#   'landscape',
#   'painting',
#   'song',
#   'dynasty',
#   'rendered',
#   'watercolor',
#   'pastel',
#   'series',
#   'nature',
#   'scene',
#   'moody',
#   'lyrical',
#   'atmospheric',
#   'lush',
#   'spare',
#   'background',
#   'subtly',
#   'suggested',
#   'stroke',
#   'brush',
#   'walt',
#   'disney',
#   'crazy',
#   'canemaker',
#   'wrote',
#   'wong',
#   'book',
#   'animation',
#   'begin',
#   'art',
#   'life',
#   'disney',
#   'inspirational',
#   'sketch',
#   'artist',
#   'love',
#   'indefinite',
#   'quality',
#   'mysterious',
#   'quality',
#   'forest',
#   'wong',
#   'unofficially',
#   'promoted',
#   'rank',
#   'inspirational',
#   'sketch',
#   'artist',
#   'canemaker',
#   'explained',
#   'designer',
#   'person',
#   'question',
#   'color',
#   'lay',
#   'influenced',
#   'music',
#   'special',
#   'effect',
#   'drawing',
#   'inspired',
#   'people',
#   'wong',
#   'spent',
#   'year',
#   'painting',
#   'illustration',
#   'inform',
#   'aspect',
#   'bambi',
#   'finished',
#   'film',
#   'lent',
#   'brooding',
#   'quality',
#   'stark',
#   'landscape',
#   'misty',
#   'desaturated',
#   'palette',
#   'figure',
#   'silhouette',
#   'influence',
#   'unmistakable',
#   'wake',
#   'bitter',
#   'employee',
#   'strike',
#   'year',
#   'disney',
#   'fired',
#   'wong',
#   'chosen',
#   'strike',
#   'felt',
#   'studio',
#   'good',
#   'canemaker',
#   'amid',
#   'lingering',
#   'climate',
#   'resentment',
#   'bambi',
#   'wong',
#   'appears',
#   'credit',
#   'mere',
#   'background',
#   'artist',
#   'wong',
#   'joined',
#   'warner',
#   'brother',
#   'working',
#   'lent',
#   'occasion',
#   'studio',
#   'retirement',
#   'indignity',
#   'endured',
#   'confined',
#   'studio',
#   'buy',
#   'house',
#   'wife',
#   'ruth',
#   'kim',
#   'told',
#   'property',
#   'inquired',
#   'sold',
#   'month',
#   'back',
#   'sign',
#   'wong',
#   'recalled',
#   'tyrus',
#   'japanese',
#   'attack',
#   'pearl',
#   'harbor',
#   'december',
#   'wong',
#   'wearing',
#   'lapel',
#   'button',
#   'proclaiming',
#   'heritage',
#   'angry',
#   'american',
#   'beat',
#   'street',
#   'war',
#   'permanently',
#   'dispersed',
#   'fledgling',
#   'oriental',
#   'artist',
#   'group',
#   'wong',
#   'friend',
#   'okubo',
#   'ten',
#   'thousand',
#   'internment',
#   'camp',
#   'world',
#   'war',
#   'ii',
#   'hadn',
#   'happened',
#   'artist',
#   'artist',
#   'today',
#   'm',
#   'movement',
#   'barely',
#   'started',
#   'split',
#   'war',
#   'wong',
#   'united',
#   'state',
#   'citizen',
#   'designed',
#   'christmas',
#   'card',
#   'hallmark',
#   'painted',
#   'elegant',
#   'design',
#   'dinnerware',
#   'sought',
#   'collector',
#   'longtime',
#   'resident',
#   'sunland',
#   'calif',
#   'retirement',
#   'renowned',
#   'kitemaker',
#   'designing',
#   'building',
#   'hand',
#   'coloring',
#   'astonishing',
#   'airworthy',
#   'creation',
#   'butterfly',
#   'swallow',
#   'flock',
#   'owl',
#   'centipede',
#   'foot',
#   'long',
#   'streaked',
#   'southern',
#   'california',
#   'sky',
#   'paint',
#   'blue',
#   'canvas',
#   'year',
#   'ruth',
#   'wong',
#   'life',
#   'ill',
#   'dementia',
#   'wong',
#   'forsook',
#   'work',
#   ...],
#  ['death',
#   'great',
#   'equalizer',
#   'isn',
#   'necessarily',
#   'evenhanded',
#   'field',
#   'endeavor',
#   'suffered',
#   'mortal',
#   'loss',
#   'muhammad',
#   'ali',
#   'arnold',
#   'palmer',
#   'sport',
#   'hollywood',
#   'death',
#   'carrie',
#   'fisher',
#   'debbie',
#   'reynolds',
#   'pop',
#   'music',
#   'world',
#   'hand',
#   'bleakest',
#   'year',
#   'start',
#   'david',
#   'bowie',
#   'stage',
#   'persona',
#   'androgynous',
#   'glam',
#   'rocker',
#   'dance',
#   'pop',
#   'star',
#   'electronic',
#   'experimentalist',
#   'music',
#   'year',
#   'day',
#   'news',
#   'died',
#   'cancer',
#   'hinted',
#   'time',
#   'short',
#   'lyric',
#   'final',
#   'album',
#   'released',
#   'day',
#   'death',
#   'great',
#   'length',
#   'hide',
#   'illness',
#   'public',
#   'privacy',
#   'ensured',
#   'death',
#   'blue',
#   'shock',
#   'month',
#   'prince',
#   'accidentally',
#   'overdosed',
#   'painkiller',
#   'collapsed',
#   'elevator',
#   'sprawling',
#   'home',
#   'studio',
#   'minneapolis',
#   'death',
#   'indication',
#   'including',
#   'prince',
#   'rogers',
#   'nelson',
#   'coming',
#   'energetic',
#   'onstage',
#   'holding',
#   'healthy',
#   'regimen',
#   'successfully',
#   'defied',
#   'age',
#   'sixth',
#   'decade',
#   'death',
#   'leonard',
#   'cohen',
#   'hand',
#   'year',
#   'undoubtedly',
#   'coming',
#   'shoulder',
#   'hesitate',
#   'merry',
#   'wise',
#   'troubadour',
#   'playing',
#   'sellout',
#   'crowd',
#   'shrugging',
#   'inevitable',
#   'knowing',
#   'dark',
#   'finally',
#   'overtake',
#   'essentially',
#   'song',
#   'hadn',
#   'delivered',
#   'jolt',
#   'system',
#   'closed',
#   'year',
#   'death',
#   'george',
#   'michael',
#   'sensation',
#   'aura',
#   'dimmed',
#   'year',
#   'bed',
#   'woke',
#   'christmas',
#   'pop',
#   'music',
#   'figure',
#   'fell',
#   'year',
#   'voice',
#   'embedded',
#   'nicked',
#   'vinyl',
#   'groove',
#   'record',
#   'lot',
#   'people',
#   'bear',
#   'throw',
#   'roster',
#   'included',
#   'paul',
#   'kantner',
#   'jefferson',
#   'airplane',
#   'keith',
#   'emerson',
#   'greg',
#   'lake',
#   'emerson',
#   'lake',
#   'palmer',
#   'glenn',
#   'frey',
#   'eagle',
#   'maurice',
#   'white',
#   'earth',
#   'wind',
#   'fire',
#   'leon',
#   'russell',
#   'piano',
#   'pounder',
#   'delta',
#   'blue',
#   'wail',
#   'mountain',
#   'man',
#   'mass',
#   'hair',
#   'died',
#   'merle',
#   'haggard',
#   'rugged',
#   'country',
#   'poet',
#   'common',
#   'man',
#   'outlaw',
#   'joined',
#   'bluegrass',
#   'legend',
#   'ralph',
#   'stanley',
#   'guitar',
#   'virtuoso',
#   'practically',
#   'glued',
#   'elvis',
#   'swiveling',
#   'hip',
#   'early',
#   'day',
#   'scotty',
#   'moore',
#   'george',
#   'martin',
#   'genius',
#   'creative',
#   'influence',
#   'sound',
#   'john',
#   'paul',
#   'george',
#   'ringo',
#   'extension',
#   'entire',
#   'rock',
#   'era',
#   'hailed',
#   'beatle',
#   'music',
#   'star',
#   'fill',
#   'arena',
#   'idol',
#   'stripe',
#   'mighty',
#   'athlete',
#   'left',
#   'scene',
#   'figure',
#   'towering',
#   'ali',
#   'called',
#   'greatest',
#   'sport',
#   'figure',
#   'century',
#   'boxer',
#   'combined',
#   'power',
#   'grace',
#   'brain',
#   'ring',
#   'great',
#   'athlete',
#   'matter',
#   'war',
#   'race',
#   'religion',
#   'coursed',
#   'life',
#   'publicly',
#   'turbulent',
#   'people',
#   'hated',
#   'refused',
#   'drafted',
#   'vietnam',
#   'war',
#   'decision',
#   'cost',
#   'heavyweight',
#   'title',
#   'people',
#   'admired',
#   'loved',
#   'principled',
#   'stand',
#   'high',
#   'spirit',
#   'lightning',
#   'mind',
#   'winking',
#   'rhyming',
#   'motormouth',
#   'illness',
#   'closed',
#   'mere',
#   'rope',
#   'ring',
#   'palmer',
#   'transformational',
#   'golf',
#   'medium',
#   'star',
#   'gentleman',
#   'game',
#   'began',
#   'gathering',
#   'army',
#   'rolling',
#   'greensward',
#   'leading',
#   'charge',
#   'shirt',
#   'coming',
#   'untucked',
#   'cigarette',
#   'dangling',
#   'lip',
#   'club',
#   'weapon',
#   'pressed',
#   'attack',
#   'entire',
#   'generation',
#   'postwar',
#   'guy',
#   'game',
#   'arnie',
#   'woman',
#   'athletically',
#   'blessed',
#   'magnetically',
#   'cool',
#   'telegenically',
#   'handsome',
#   'gordie',
#   'howe',
#   'hockey',
#   'son',
#   'saskatchewan',
#   'prairie',
#   'tore',
#   'national',
#   'hockey',
#   'league',
#   'hung',
#   'skate',
#   'died',
#   'ralph',
#   'branca',
#   'trolley',
#   'car',
#   'conductor',
#   'son',
#   'living',
#   'reminder',
#   'crushing',
#   'mistake',
#   'fastball',
#   'bobby',
#   'thomson',
#   'decided',
#   'national',
#   'league',
#   'pennant',
#   'lived',
#   'pat',
#   'summitt',
#   'coach',
#   'elevated',
#   'woman',
#   'basketball',
#   'led',
#   'tennessee',
#   'team',
#   'championship',
#   'won',
#   'game',
#   'college',
#   'coach',
#   'defeat',
#   'alzheimer',
#   'disease',
#   'dying',
#   'month',
#   'national',
#   'basketball',
#   'association',
#   'lost',
#   'giant',
#   'era',
#   'clyde',
#   'lovelette',
#   'olympic',
#   'college',
#   'champion',
#   'transformed',
#   'game',
#   'big',
#   'men',
#   'hardwood',
#   'heir',
#   'nate',
#   'thurmond',
#   'defensive',
#   'stalwart',
#   'battled',
#   'russell',
#   'wilt',
#   'kareem',
#   'paint',
#   'hall',
#   'fame',
#   'career',
#   'older',
#   'baseball',
#   'rank',
#   'monte',
#   'irvin',
#   'died',
#   'people',
#   'remember',
#   'watching',
#   'play',
#   'prime',
#   'star',
#   'negro',
#   'circuit',
#   'barred',
#   'major',
#   'league',
#   'made',
#   'hall',
#   'fame',
#   'york',
#   'giant',
#   'major',
#   'league',
#   'baseball',
#   'black',
#   'executive',
#   'died',
#   'fan',
#   'pondered',
#   'question',
#   'hung',
#   'athletic',
#   'career',
#   'shackled',
#   'discrimination',
#   'question',
#   'sphere',
#   'arose',
#   'stunning',
#   'news',
#   'justice',
#   'antonin',
#   'scalia',
#   'died',
#   'hunting',
#   'trip',
#   'texas',
#   'thick',
#   'consequential',
#   'supreme',
#   'court',
#   'career',
#   'modern',
#   'time',
#   'left',
#   'void',
#   'conservative',
#   'jurisprudence',
#   'urgently',
#   'vacancy',
#   'bench',
#   'filled',
#   'raising',
#   'question',
#   'await',
#   'country',
#   'exit',
#   'public',
#   'stage',
#   'returned',
#   'past',
#   'nancy',
#   'reagan',
#   'death',
#   'evoked',
#   'white',
#   'house',
#   'glamour',
#   'west',
#   'coast',
#   'conservatism',
#   'residence',
#   'bank',
#   'potomac',
#   'john',
#   'glenn',
#   'thinking',
#   'burst',
#   'national',
#   'pride',
#   'soaring',
#   'outer',
#   'space',
#   'death',
#   'tom',
#   'hayden',
#   'daniel',
#   'berrigan',
#   'avatar',
#   'defiance',
#   'harked',
#   'back',
#   'student',
#   'rebellion',
#   'vietnam',
#   'war',
#   'roiling',
#   'home',
#   'front',
#   'phyllis',
#   'schlafly',
#   'obituary',
#   'window',
#   'root',
#   'wing',
#   'ascension',
#   'american',
#   'politics',
#   'death',
#   'janet',
#   'reno',
#   'woman',
#   'serve',
#   'attorney',
#   'general',
#   'recalled',
#   'clinton',
#   'year',
#   'firestorm',
#   'waco',
#   'tex',
#   'international',
#   'tug',
#   'war',
#   'cuban',
#   'boy',
#   'named',
#   'eli',
#   'gonz',
#   'lez',
#   'bitter',
#   'senate',
#   'battle',
#   'impeachment',
#   'shore',
#   'fidel',
#   'castro',
#   'death',
#   'summoned',
#   'memory',
#   'cuban',
#   'revolution',
#   'nuclear',
#   'brinkmanship',
#   'enduring',
#   'enmity',
#   'strongman',
#   'superpower',
#   'mile',
#   'boutros',
#   'egyptian',
#   'diplomat',
#   'led',
#   'united',
#   'nation',
#   'led',
#   'replayed',
#   'nightmare',
#   'genocide',
#   'rwanda',
#   'bosnia',
#   'death',
#   'shimon',
#   'peres',
#   'removed',
#   'link',
#   'founding',
#   'israel',
#   'conjured',
#   'decade',
#   'growing',
#   'military',
#   'power',
#   'fitful',
#   'striving',
#   'peace',
#   'elie',
#   'wiesel',
#   'york',
#   'tireless',
#   'struggle',
#   'compel',
#   'world',
#   'forget',
#   'made',
#   'confront',
#   'gas',
#   'chamber',
#   'auschwitz',
#   'writer',
#   'fiction',
#   'world',
#   'poorer',
#   'literary',
#   'voice',
#   'harper',
#   'lee',
#   'umberto',
#   'eco',
#   'pat',
#   'conroy',
#   'jim',
#   'harrison',
#   'anita',
#   'brookner',
#   'alvin',
#   'toffler',
#   'gloria',
#   'naylor',
#   'william',
#   'trevor',
#   'mention',
#   'playwright',
#   'peter',
#   'shaffer',
#   'dario',
#   'fo',
#   'edward',
#   'albee',
#   'dead',
#   'treasured',
#   'spun',
#   'viewing',
#   'pleasure',
#   'lustily',
#   'm',
#   'fisher',
#   'princess',
#   'leia',
#   'star',
#   'war',
#   'tale',
#   'day',
#   'capping',
#   'year',
#   'startling',
#   'death',
#   'm',
#   'reynolds',
#   'singing',
#   'acting',
#   'leading',
#   'lady',
#   'earlier',
#   'era',
#   'died',
#   'throe',
#   'mother',
#   'grief',
#   'devotee',
#   'harry',
#   'potter',
#   'movie',
#   'saddened',
#   'death',
#   'alan',
#   'rickman',
#   'played',
#   'deliciously',
#   'dour',
#   'professor',
#   'severus',
#   'snape',
#   'blockbuster',
#   'franchise',
#   'career',
#   'stage',
#   'screen',
#   'richer',
#   'snape',
#   'younger',
#   'fan',
#   'zsa',
#   'zsa',
#   'gabor',
#   'celebrity',
#   'contrast',
#   'outshone',
#   'modest',
#   'acting',
#   'career',
#   'gene',
#   'wilder',
#   'garry',
#   'shandling',
#   'died',
#   'year',
#   'perfected',
#   'brand',
#   'hilariously',
#   'neurotic',
#   'comedy',
#   'fit',
#   'culture',
#   'time',
#   'abe',
#   'vigoda',
#   'godfather',
#   'movie',
#   'barney',
#   'miller',
#   'die',
#   'year',
#   'ago',
#   'wildly',
#   'uninformed',
#   'people',
#   'spread',
#   'word',
#   'side',
#   'camera',
#   'director',
#   'vision',
#   'part',
#   'jacques',
#   'rivette',
#   'french',
#   'wave',
#   'auteur',
#   'meditation',
#   'life',
#   'art',
#   'abbas',
#   'kiarostami',
#   'iranian',
#   'master',
#   'searching',
#   'examination',
#   'ordinary',
#   'life',
#   'andrzej',
#   'wajda',
#   'rival',
#   'ingmar',
#   'bergman',
#   'akira',
#   'kurosawa',
#   'critic',
#   'eye',
#   'haunting',
#   'tale',
#   'poland',
#   'boot',
#   'nazi',
#   'communist',
#   'long',
#   'roster',
#   'television',
#   'star',
#   'generation',
#   'ago',
#   'passed',
#   'image',
#   'younger',
#   'frozen',
#   'time',
#   'noel',
#   'neill',
#   'adventure',
#   'superman',
#   'alan',
#   'young',
#   'mister',
#   'ed',
#   'robert',
#   'vaughn',
#   'man',
#   'william',
#   'schallert',
#   'patty',
#   'duke',
#   'father',
#   'daughter',
#   'patty',
#   'duke',
#   'show',
#   'dan',
#   'haggerty',
#   'life',
#   'time',
#   'grizzly',
#   'adam',
#   'florence',
#   'henderson',
#   'brady',
#   'bunch',
#   'alan',
#   'thicke',
#   'growing',
#   'pain',
#   'garry',
#   'marshall',
#   'creative',
#   'force',
#   'practically',
#   'owned',
#   'prime',
#   'time',
#   'happy',
#   'day',
#   'mork',
#   'mindy',
#   'laverne',
#   'shirley',
#   'died',
#   'broadway',
#   'light',
#   'dimmed',
#   'memory',
#   'brian',
#   'bedford',
#   'tammy',
#   'grime',
#   'anne',
#   'jackson',
#   'brilliant',
#   'day',
#   'architect',
#   'zaha',
#   'hadid',
#   'left',
#   'monument',
#   'fertile',
#   'imagination',
#   'shaken',
#   'acolyte',
#   'world',
#   'street',
#   'photographer',
#   'bill',
#   'cunningham',
#   'found',
#   'fashion',
#   'statement',
#   'corner',
#   'suddenly',
#   'missing',
#   'making',
#   'manhattan',
#   'overnight',
#   'idiosyncratic',
#   'interesting',
#   'place',
#   'smiling',
#   'skinny',
#   'man',
#   'pedaling',
#   'bicycle',
#   'honking',
#   'cab',
#   'blue',
#   'french',
#   'worker',
#   'jacket',
#   'camera',
#   'slung',
#   'neck',
#   'picture',
#   'split',
#   'scene',
#   'seemingly',
#   'generation',
#   'fellow',
#   'photographer',
#   'made',
#   'art',
#   'recording',
#   'half',
#   'century',
#   'ruth',
#   'gruber',
#   'marc',
#   'riboud',
#   'louis',
#   'stettner',
#   'tv',
#   'journalist',
#   'morley',
#   'safer',
#   'gwen',
#   'ifill',
#   'tv',
#   'commentator',
#   'john',
#   'mclaughlin',
#   'make',
#   'sense',
#   'music',
#   'precinct',
#   'emptier',
#   'conductor',
#   'revolutionary',
#   'composer',
#   'pierre',
#   'boulez',
#   'music',
#   'soprano',
#   'phyllis',
#   'curtin',
#   'jazz',
#   'artist',
#   'mose',
#   'allison',
#   'bobby',
#   'hutcherson',
#   'gato',
#   'barbieri',
#   'rapper',
#   'phife',
#   'dawg',
#   'malik',
#   'taylor',
#   'latin',
#   'megastar',
#   'juan',
#   'gabriel',
#   'silicon',
#   'valley',
#   'giant',
#   'depart',
#   'andrew',
#   'grove',
#   'led',
#   'semiconductor',
#   'revolution',
#   'intel',
#   'television',
#   'industry',
#   'lost',
#   'executive',
#   'grant',
#   'tinker',
#   'made',
#   'nbc',
#   'network',
#   'watch',
#   'prime',
#   'time',
#   'astrophysics',
#   'smaller',
#   'world',
#   'woman',
#   'science',
#   'farewell',
#   'pioneer',
#   'champion',
#   'vera',
#   'rubin',
#   'ten',
#   'thousand',
#   'people',
#   'choked',
#   'death',
#   'saved',
#   'simple',
#   'ingenious',
#   'maneuver',
#   'passing',
#   'henry',
#   'heimlich',
#   'prompted',
#   'sympathy',
#   'gratitude',
#   'eliciting',
#   'large',
#   'silent',
#   'live',
#   'bad',
#   'brings',
#   'marion',
#   'pritchard',
#   'died',
#   'inspired',
#   'measure',
#   'gratitude',
#   'profound',
#   'brave',
#   'young',
#   'dutch',
#   'student',
#   'gentile',
#   'risked',
#   'life',
#   'save',
#   'jew',
#   'death',
#   'camp',
#   'early',
#   'instance',
#   'shooting',
#   'nazi',
#   ...],
#  ['seoul',
#   'south',
#   'korea',
#   'north',
#   'korea',
#   'leader',
#   'kim',
#   'sunday',
#   'country',
#   'making',
#   'final',
#   'preparation',
#   'conduct',
#   'test',
#   'intercontinental',
#   'ballistic',
#   'missile',
#   'bold',
#   'statement',
#   'month',
#   'inauguration',
#   'donald',
#   'trump',
#   'north',
#   'korea',
#   'conducted',
#   'nuclear',
#   'test',
#   'decade',
#   'ballistic',
#   'missile',
#   'test',
#   'habitually',
#   'threatens',
#   'attack',
#   'united',
#   'state',
#   'nuclear',
#   'weapon',
#   'country',
#   'intercontinental',
#   'ballistic',
#   'missile',
#   'icbm',
#   'annual',
#   'year',
#   'day',
#   'speech',
#   'broadcast',
#   'north',
#   'kctv',
#   'sunday',
#   'kim',
#   'spoke',
#   'proudly',
#   'stride',
#   'country',
#   'made',
#   'nuclear',
#   'weapon',
#   'ballistic',
#   'missile',
#   'program',
#   'north',
#   'korea',
#   'continue',
#   'bolster',
#   'weapon',
#   'program',
#   'long',
#   'united',
#   'state',
#   'remained',
#   'hostile',
#   'continued',
#   'joint',
#   'military',
#   'exercise',
#   'south',
#   'korea',
#   'reached',
#   'final',
#   'stage',
#   'preparation',
#   'intercontinental',
#   'ballistic',
#   'rocket',
#   'analyst',
#   'region',
#   'kim',
#   'conduct',
#   'weapon',
#   'test',
#   'coming',
#   'month',
#   'taking',
#   'advantage',
#   'leadership',
#   'united',
#   'state',
#   'south',
#   'korea',
#   'trump',
#   'sworn',
#   'jan',
#   'south',
#   'korea',
#   'president',
#   'park',
#   'power',
#   'suspended',
#   'parliamentary',
#   'impeachment',
#   'dec',
#   'waiting',
#   'constitutional',
#   'court',
#   'rule',
#   'formally',
#   'removed',
#   'office',
#   'reinstated',
#   'north',
#   'korea',
#   'conduct',
#   'test',
#   'coming',
#   'month',
#   'test',
#   'trump',
#   'administration',
#   'year',
#   'increasingly',
#   'harsh',
#   'sanction',
#   'north',
#   'korea',
#   'advancing',
#   'kim',
#   'professed',
#   'goal',
#   'arming',
#   'isolated',
#   'country',
#   'ability',
#   'deliver',
#   'nuclear',
#   'warhead',
#   'united',
#   'state',
#   'kim',
#   'speech',
#   'sunday',
#   'north',
#   'korea',
#   'rocket',
#   'time',
#   'year',
#   'complete',
#   'icbm',
#   'program',
#   'cheong',
#   'senior',
#   'research',
#   'fellow',
#   'sejong',
#   'institute',
#   'south',
#   'korea',
#   'test',
#   'trump',
#   'inauguration',
#   'cheong',
#   'note',
#   'fact',
#   'year',
#   'speech',
#   'kim',
#   'mentioned',
#   'intercontinental',
#   'ballistic',
#   'missile',
#   'speech',
#   'kim',
#   'comment',
#   'trump',
#   'election',
#   'doubt',
#   'run',
#   'deep',
#   'north',
#   'korea',
#   'mastered',
#   'technology',
#   'needed',
#   'build',
#   'reliable',
#   'icbm',
#   'analyst',
#   'region',
#   'north',
#   'launching',
#   'rocket',
#   'put',
#   'satellite',
#   'orbit',
#   'recent',
#   'year',
#   'showed',
#   'country',
#   'cleared',
#   'key',
#   'technological',
#   'hurdle',
#   'north',
#   'satellite',
#   'launch',
#   'february',
#   'south',
#   'korean',
#   'defense',
#   'official',
#   'unha',
#   'rocket',
#   'launch',
#   'successfully',
#   'reconfigured',
#   'missile',
#   'fly',
#   'mile',
#   'warhead',
#   'pound',
#   'reach',
#   'united',
#   'state',
#   'north',
#   'korea',
#   'deployed',
#   'rodong',
#   'ballistic',
#   'missile',
#   'reach',
#   'south',
#   'korea',
#   'japan',
#   'spotty',
#   'record',
#   'musudan',
#   'ballistic',
#   'missile',
#   'range',
#   'long',
#   'reach',
#   'american',
#   'military',
#   'base',
#   'pacific',
#   'including',
#   'guam',
#   'north',
#   'claimed',
#   'series',
#   'success',
#   'testing',
#   'icbm',
#   'technology',
#   'claim',
#   'verified',
#   'disputed',
#   'official',
#   'analyst',
#   'region',
#   'make',
#   'nuclear',
#   'warhead',
#   'small',
#   'fit',
#   'ballistic',
#   'missile',
#   'claimed',
#   'success',
#   'testing',
#   'technology',
#   'missile',
#   'return',
#   'earth',
#   'atmosphere',
#   'breaking',
#   'april',
#   'north',
#   'korea',
#   'reported',
#   'successful',
#   'ground',
#   'test',
#   'engine',
#   'intercontinental',
#   'ballistic',
#   'missile',
#   'time',
#   'kim',
#   'north',
#   'tip',
#   'intercontinental',
#   'ballistic',
#   'rocket',
#   'powerful',
#   'nuclear',
#   'warhead',
#   'cesspool',
#   'evil',
#   'earth',
#   'including',
#   'mainland',
#   'striking',
#   'range',
#   'sept',
#   'north',
#   'conducted',
#   'powerful',
#   'nuclear',
#   'test',
#   'kim',
#   'attended',
#   'ground',
#   'test',
#   'rocket',
#   'engine',
#   'exhorting',
#   'government',
#   'prepare',
#   'rocket',
#   'launch',
#   'november',
#   'united',
#   'nation',
#   'security',
#   'council',
#   'imposed',
#   'sanction',
#   'north']]

# %% [markdown]
# # Automated Keyword Extraction
#
# > Automatic identification of terms that best describe the subject of a document. Key phrases, key terms, key segments or just keywords are the terminology which is used for defining the terms that represent the most relevant information contained in the document.
#
# Method used: TfidfVectorizer
#
# Reference: http://kavita-ganesan.com/extracting-keywords-from-text-tfidf/#.XLX1EUPhXeQ

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import coo_matrix 

def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)
 
def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    sorted_items = sorted_items[:topn]
    score_vals = []
    feature_vals = []
    
    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
 
    results = {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]] = score_vals[idx]
    
    return results

tv = TfidfVectorizer(max_df=1, min_df = 0.05, stop_words=stop_words, max_features=10000, 
                                ngram_range=(1,3), smooth_idf=True, use_idf=True)
kw = []

for index in df['index']:
    
    tfidf_matrix = tv.fit_transform([corpus[index]])
    feature_names = tv.get_feature_names()
    
    sorted_items = sort_coo(tfidf_matrix.tocoo())
    keywords = extract_topn_from_vector(feature_names, sorted_items, topn=100)
    # keywords = {'republican': 0.296, 'house republican': 0.276, ...} <- for index = 0
    #            {'precinct': 0.586, 'detective': 0.403, ...} <- for index = 1
    
    kw.append(list(keywords.keys())) 

df['keywords'] = kw
df.head(5)
# Out:
#    index     id                                              title  \
# 0      0  17283  House Republicans Fret About Winning Their Hea...
# 1      1  17284  Rift Between Officers and Residents as Killing...
# 2      2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content  \
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...
#
#                                             keywords
# 0  [house, republican, administration, health, tr...
# 1  [precinct, detective, police, officer, year, f...
# 2  [wong, artist, disney, father, work, tyrus, ch...
# 3  [death, died, year, time, people, star, music,...
# 4  [north, korea, missile, ballistic, test, north...

# %% [markdown]
# # Topic Modelling
#
# > Statistical modeling for discovering the abstract “topics” that occur in a collection of documents
#
# Methods used: LDA (Latent Dirichlet Allocation)
#
# Reference: https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html

# %%
df['lda_topics'] = ''

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

no_features = 1000
no_topic = 1
no_top_words = 10

for index in df['index']:

    tf_vec = CountVectorizer(max_df = 0.95, min_df = 1, max_features=no_features)
    tf_mat = tf_vec.fit_transform(corpus_list[index])
    tf_feature_names = tf_vec.get_feature_names()
    
    lda = LatentDirichletAllocation(n_components=no_topic, 
                                    max_iter=5, 
                                    learning_method = 'online', 
                                    learning_offset=50., 
                                    random_state=0
                                   ).fit(tf_mat)
    
    for topic_index, topic in enumerate(lda.components_):
        df.lda_topics[index] = [tf_feature_names[i] for i in topic.argsort()[:-no_top_words -1:-1]]
        
df.head(5)
# Out:
#    index     id                                              title  \
# 0      0  17283  House Republicans Fret About Winning Their Hea...
# 1      1  17284  Rift Between Officers and Residents as Killing...
# 2      2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content  \
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...
#
#                                             keywords  \
# 0  [house, republican, administration, health, tr...
# 1  [precinct, detective, police, officer, year, f...
# 2  [wong, artist, disney, father, work, tyrus, ch...
# 3  [death, died, year, time, people, star, music,...
# 4  [north, korea, missile, ballistic, test, north...
#
#                                           lda_topics
# 0  [house, republican, administration, health, tr...
# 1  [precinct, detective, fernandez, officer, poli...
# 2  [wong, disney, artist, father, work, chinese, ...
# 3  [death, died, year, time, people, life, day, m...
# 4  [north, korea, missile, ballistic, test, kim, ...

# %% [markdown]
# # Document Classification
#
# > Assign a document to one or more classes or categories
#
# Methods Used: Jaccard Similarity & Cosine Similarity
#
# Reference: https://towardsdatascience.com/overview-of-text-similarity-metrics-3397c4601f50

# %%
def file_to_list(file):
    path = '/home/pratikshasahu/Documents/EIDETIA/env/data/'
    path += file
    return [line.rstrip('\n') for line in open(path)]

p_list = file_to_list('politics')
b_list = file_to_list('business')
e_list = file_to_list('entertainment')
s_list = file_to_list('sports')
t_list = file_to_list('technology')

df['category_js'] = ''

def jaccard_sim(str1, str2): 
    a = set(str1) 
    b = set(str2)
    c = a.intersection(b)
    res = float(len(c)) / (len(a) + len(b) - len(c))
    return res
     
for x in df['index']:
    
    p_js = jaccard_sim(df['keywords'][x], p_list)
    b_js = jaccard_sim(df['keywords'][x], b_list) 
    e_js = jaccard_sim(df['keywords'][x], e_list) 
    s_js = jaccard_sim(df['keywords'][x], s_list) 
    t_js = jaccard_sim(df['keywords'][x], t_list) 
    
    js = max(p_js, b_js, e_js, s_js, t_js)
    if js == p_js:
        df['category_js'][x] = 'politics'
    elif js == b_js:
        df['category_js'][x] = 'business'
    elif js == e_js:
        df['category_js'][x] = 'entertainment'
    elif js == s_js:
        df['category_js'][x] = 'sports'
    else:
        df['category_js'][x] = 'tech'
        
df.head(10)
# Out:
#    index     id                                              title  \
# 0      0  17283  House Republicans Fret About Winning Their Hea...
# 1      1  17284  Rift Between Officers and Residents as Killing...
# 2      2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      4  17287  Kim Jong-un Says North Korea Is Preparing to T...
# 5      5  17288  Sick With a Cold, Queen Elizabeth Misses New Y...
# 6      6  17289  Taiwan’s President Accuses China of Renewed In...
# 7      7  17290  After ‘The Biggest Loser,’ Their Bodies Fought...
# 8      8  17291  First, a Mixtape. Then a Romance. - The New Yo...
# 9      9  17292  Calling on Angels While Enduring the Trials of...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
# 5  New York Times                    Sewell Chan  2017-01-02  2017.0    1.0
# 6  New York Times            Javier C. Hernández  2017-01-02  2017.0    1.0
# 7  New York Times                    Gina Kolata  2017-02-08  2017.0    2.0
# 8  New York Times               Katherine Rosman  2016-12-31  2016.0   12.0
# 9  New York Times                    Andy Newman  2016-12-31  2016.0   12.0
#
#    url                                            content  \
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...
# 5  NaN  LONDON  —   Queen Elizabeth II, who has been b...
# 6  NaN  BEIJING  —   President Tsai   of Taiwan sharpl...
# 7  NaN  Danny Cahill stood, slightly dazed, in a blizz...
# 8  NaN  Just how   is Hillary Kerr, the    founder of ...
# 9  NaN  Angels are everywhere in the Muñiz family’s ap...
#
#                                             keywords  \
# 0  [house, republican, administration, health, tr...
# 1  [precinct, detective, police, officer, year, f...
# 2  [wong, artist, disney, father, work, tyrus, ch...
# 3  [death, died, year, time, people, star, music,...
# 4  [north, korea, missile, ballistic, test, north...
# 5  [queen, church, service, year, week, sandringh...
# 6  [tsai, taiwan, china, beijing, trump, island, ...
# 7  [weight, calorie, pound, people, contestant, d...
# 8  [kerr, leahy, friend, music, song, made, met, ...
# 9  [mu, mu iz, iz, family, angel, jos, time, chil...
#
#                                           lda_topics    category_js
# 0  [house, republican, administration, health, tr...       politics
# 1  [precinct, detective, fernandez, officer, poli...       politics
# 2  [wong, disney, artist, father, work, chinese, ...  entertainment
# 3  [death, died, year, time, people, life, day, m...  entertainment
# 4  [north, korea, missile, ballistic, test, kim, ...       politics
# 5  [queen, church, service, day, missed, year, mo...       politics
# 6  [tsai, taiwan, china, visit, beijing, transit,...       politics
# 7  [weight, calorie, people, pound, dr, contestan...           tech
# 8  [kerr, leahy, friend, music, song, made, bride...  entertainment
# 9  [mu, iz, family, angel, jos, time, child, york...       business

# %%
from sklearn.metrics.pairwise import cosine_similarity

def file_to_str(file):
    path = '/home/pratikshasahu/Documents/EIDETIA/env/data/'
    path += file
    return ' '.join([line.rstrip('\n') for line in open(path)])

b_str = file_to_str('business')
p_str = file_to_str('politics')
e_str = file_to_str('entertainment')
s_str = file_to_str('sports')
t_str = file_to_str('technology')

df['category_cs'] = ''

def cosine_sim(*strs): 
    text = [t for t in strs]
    vectorizer = TfidfVectorizer()
    vectorizer.fit(text)
    get_vectors = vectorizer.transform(text).toarray()
    
    vectors = [t for t in get_vectors]
    return cosine_similarity(vectors)[0][1]   
    

for x in df['index']:
    
    p_cs = cosine_sim(' '.join(df['keywords'][x]), p_str)
    b_cs = cosine_sim(' '.join(df['keywords'][x]), b_str)
    e_cs = cosine_sim(' '.join(df['keywords'][x]), e_str)
    s_cs = cosine_sim(' '.join(df['keywords'][x]), s_str)
    t_cs = cosine_sim(' '.join(df['keywords'][x]), t_str)
    
    cs = max(p_cs, b_cs, t_cs, e_cs, s_cs)
    if cs == p_cs:
        df['category_cs'][x] = 'politics'
    elif cs == b_cs:
        df['category_cs'][x] = 'business'
    elif cs == e_cs:
        df['category_cs'][x] = 'entertainment'
    elif cs == s_cs:
        df['category_cs'][x] = 'sports'
    else:
        df['category_cs'][x] = 'tech'

df.head(10)
# Out:
#    index     id                                              title  \
# 0      0  17283  House Republicans Fret About Winning Their Hea...
# 1      1  17284  Rift Between Officers and Residents as Killing...
# 2      2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      4  17287  Kim Jong-un Says North Korea Is Preparing to T...
# 5      5  17288  Sick With a Cold, Queen Elizabeth Misses New Y...
# 6      6  17289  Taiwan’s President Accuses China of Renewed In...
# 7      7  17290  After ‘The Biggest Loser,’ Their Bodies Fought...
# 8      8  17291  First, a Mixtape. Then a Romance. - The New Yo...
# 9      9  17292  Calling on Angels While Enduring the Trials of...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
# 5  New York Times                    Sewell Chan  2017-01-02  2017.0    1.0
# 6  New York Times            Javier C. Hernández  2017-01-02  2017.0    1.0
# 7  New York Times                    Gina Kolata  2017-02-08  2017.0    2.0
# 8  New York Times               Katherine Rosman  2016-12-31  2016.0   12.0
# 9  New York Times                    Andy Newman  2016-12-31  2016.0   12.0
#
#    url                                            content  \
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...
# 5  NaN  LONDON  —   Queen Elizabeth II, who has been b...
# 6  NaN  BEIJING  —   President Tsai   of Taiwan sharpl...
# 7  NaN  Danny Cahill stood, slightly dazed, in a blizz...
# 8  NaN  Just how   is Hillary Kerr, the    founder of ...
# 9  NaN  Angels are everywhere in the Muñiz family’s ap...
#
#                                             keywords  \
# 0  [house, republican, administration, health, tr...
# 1  [precinct, detective, police, officer, year, f...
# 2  [wong, artist, disney, father, work, tyrus, ch...
# 3  [death, died, year, time, people, star, music,...
# 4  [north, korea, missile, ballistic, test, north...
# 5  [queen, church, service, year, week, sandringh...
# 6  [tsai, taiwan, china, beijing, trump, island, ...
# 7  [weight, calorie, pound, people, contestant, d...
# 8  [kerr, leahy, friend, music, song, made, met, ...
# 9  [mu, mu iz, iz, family, angel, jos, time, chil...
#
#                                           lda_topics    category_js  \
# 0  [house, republican, administration, health, tr...       politics
# 1  [precinct, detective, fernandez, officer, poli...       politics
# 2  [wong, disney, artist, father, work, chinese, ...  entertainment
# 3  [death, died, year, time, people, life, day, m...  entertainment
# 4  [north, korea, missile, ballistic, test, kim, ...       politics
# 5  [queen, church, service, day, missed, year, mo...       politics
# 6  [tsai, taiwan, china, visit, beijing, transit,...       politics
# 7  [weight, calorie, people, pound, dr, contestan...           tech
# 8  [kerr, leahy, friend, music, song, made, bride...  entertainment
# 9  [mu, iz, family, angel, jos, time, child, york...       business
#
#      category_cs
# 0       politics
# 1       business
# 2  entertainment
# 3  entertainment
# 4           tech
# 5         sports
# 6         sports
# 7           tech
# 8  entertainment
# 9  entertainment

# %%
df.query('category_js != category_cs')
# Out:
#      index     id                                              title  \
# 1        1  17284  Rift Between Officers and Residents as Killing...
# 4        4  17287  Kim Jong-un Says North Korea Is Preparing to T...
# 5        5  17288  Sick With a Cold, Queen Elizabeth Misses New Y...
# 6        6  17289  Taiwan’s President Accuses China of Renewed In...
# 9        9  17292  Calling on Angels While Enduring the Trials of...
# 10      10  17293  Weak Federal Powers Could Limit Trump’s Climat...
# 11      11  17294  Can Carbon Capture Technology Prosper Under Tr...
# 12      12  17295  Mar-a-Lago, the Future Winter White House and ...
# 13      13  17296  How to form healthy habits in your 20s - The N...
# 14      14  17297  Turning Your Vacation Photos Into Works of Art...
# 15      15  17298  As Second Avenue Subway Opens, a Train Delay E...
# 17      17  17301  Modi’s Cash Ban Brings Pain, but Corruption-We...
# 18      18  17302  Suicide Bombing in Baghdad Kills at Least 36 -...
# 19      19  17303  Fecal Pollution Taints Water at Melbourne’s Be...
# 22      22  17307  Damaged by War, Syria’s Cultural Sites Rise An...
# 24      24  17309  With New Congress Poised to Convene, Obama’s P...
# 26      26  17312  Istanbul, Donald Trump, Benjamin Netanyahu: Yo...
# 29      29  17317  The Afghan War and the Evolution of Obama - Th...
# 30      30  17318  Tips for Your Post-Holiday Clutter Purge - The...
# 31      31  17319  Benjamin Netanyahu Questioned in Israel Graft ...
# 34   RIO DE JANEIRO  —   A prison riot involving ga...
# 35   After the explosion in September of one of its...
# 39   WASHINGTON  —   It was supposed to be a triump...
# 40    (Want to get this briefing by email? Here’s t...
# 43   ■   Donald J. Trump appears to side with the W...
# 47   It’s that time of year when financial advice s...
# 48   For Megyn Kelly, the shift from Fox News to NB...
# 53   A steep drop in gang violence last year drove ...
# 54   Our new president is a    billionaire Ivy Leag...
# ..                                                 ...
# 944  The White House has issued a list of 78 terror...
# 945  Good morning.  Here’s what you need to know: •...
# 946  Good morning. (Want to get California Today by...
# 947  ROME  —   When Stephen K. Bannon was still hea...
# 948  A lawsuit filed by Melania Trump depicts her h...
# 950  WASHINGTON  —   Andrew F. Puzder, who as Presi...
# 953  Rebecca Blumenstein, deputy editor in chief of...
# 955  Thousands of years ago, every lake was like Gr...
# 958  Faiz Khalil was a colonel in the Iraqi Army wh...
# 959  In an article that appeared online in The Mail...
# 963  Hours before the start of the Women’s March on...
# 964  You never know when a frog playing an electron...
# 965  That was fast. Two weeks after her “America Fi...
# 966  A fiery meteor streaked across the Midwest sky...
# 970  The last time we saw John Oliver on “Last Week...
# 972  WASHINGTON  —   Republicans seized her microph...
# 974  WASHINGTON  —   Although there is plenty of an...
# 975  WASHINGTON  —   President Trump lashed out on ...
# 977  AURORA, Colo.  —   It took 11 days of calling ...
# 979  WASHINGTON  —   Margaret Thatcher famously dec...
# 983  MANILA  —   A fire raced through a squalid Man...
# 984  The New York Times Magazine won three National...
# 986  DENVER  —   The Army approved the construction...
# 987  PARIS  —   Former President Nicolas Sarkozy ha...
# 988  LONDON  —   In November 1967, four years after...
# 990  Some are disarmingly named, like the cutesy Ch...
# 992  ATLANTA  —   What, exactly, do you do with a  ...
# 993  For anyone wondering how former President Bara...
# 995  Many of the world’s winter athletes, now prepa...
# 999  Damien Chazelle, the writer and director of th...
#
#                                               keywords  \
# 1    [precinct, detective, police, officer, year, f...
# 4    [north, korea, missile, ballistic, test, north...
# 5    [queen, church, service, year, week, sandringh...
# 6    [tsai, taiwan, china, beijing, trump, island, ...
# 9    [mu, mu iz, iz, family, angel, jos, time, chil...
# 10   [trump, energy, global, wind, state, climate, ...
# 11   [carbon, capture, carbon capture, plant, techn...
# 12   [trump, club, member, guest, year, club member...
# 13   [habit, reward, time, exercise, cue, start, in...
# 14   [photo, print, site, scan, time, wood, fabric,...
# 15   [subway, station, line, train, city, street, s...
# 17   [modi, ban, cash, corruption, economy, india, ...
# 18   [attack, state, baghdad, laborer, islamic stat...
# 19   [water, beach, summer, rain, pollution, city, ...
# 22   [site, war, syria, syrian, ubelmann, show, par...
# 24   [senate, republican, trump, year, democrat, le...
# 26   [limit, year, time, york time, york, state, sp...
# 29   [obama, afghanistan, war, american, state, tro...
# 30   [drawer, toy, organizer, lowenheim, piece, don...
# 31   [netanyahu, prime minister, prime, minister, i...
# 33   [pilot, police, canada, calgary, airport, tran...
# 34   [prison, riot, gang, manaus, inmate, paulo, of...
# 35   [spacex, oxygen, satellite, launch, rocket, he...
